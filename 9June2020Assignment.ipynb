# %%
import pandas as pd
import numpy as np
r=pd.read_csv('https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv')
r
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# ...

# %%
a=r.groupby("City_Name")
a

# %%
a.get_group("Hyderabad")
# Out:
#      Match_SK  match_id                Team1                        Team2  \
# 6           6    335993      Deccan Chargers             Delhi Daredevils
# 8           8    335995      Deccan Chargers             Rajasthan Royals
# 17         17    336004      Deccan Chargers              Kings XI Punjab
# 20         20    336007      Deccan Chargers  Royal Challengers Bangalore
# 32         32    336019      Deccan Chargers        Kolkata Knight Riders
# 42         42    336029      Deccan Chargers               Mumbai Indians
# 54         54    336042      Deccan Chargers          Chennai Super Kings
# 176       176    501204      Deccan Chargers             Rajasthan Royals
# 185       185    501213      Deccan Chargers  Royal Challengers Bangalore
# 189       189    501217      Deccan Chargers              Kings XI Punjab
# 200       200    501229      Deccan Chargers               Mumbai Indians
# 215       215    501244      Deccan Chargers        Kolkata Knight Riders
# ...

# %%
z=a.get_group('Hyderabad')["ManOfMach"]
df=pd.DataFrame(z)
df
# Out:
#              ManOfMach
# 6             V Sehwag
# 8            YK Pathan
# 17            SE Marsh
# 20       R Vinay Kumar
# 32          SC Ganguly
# 42            DJ Bravo
# 54            SK Raina
# 176         SK Trivedi
# 185           DW Steyn
# 189        PC Valthaty
# 200         SL Malinga
# 215          YK Pathan
# 219           V Sehwag
# 226           MR Marsh
# 271          DA Warner
# 299      Mandeep Singh
# 313           DW Steyn
# 316           DW Steyn
# 324           A Mishra
# 328          GH Vihari
# 345          GH Vihari
# 363           I Sharma
# 368          DJG Sammy
# 375           SK Raina
# 389           A Mishra
# 393           PA Patel
# 433          AT Rayudu
# 436            WP Saha
# 440           UT Yadav
# 443          DA Warner
# 491          DA Warner
# 504          DA Warner
# 508            V Kohli
# 512     MJ McClenaghan
# 524          G Gambhir
# 528          DA Warner
# 534  Mustafizur Rahman
# 538           AB Dinda
# 543          DA Warner
# ...

# %%
s=pd.DataFrame(Number)
s
# Out:
#                    0
# ManOfMach
# A Mishra           2
# AB Dinda           1
# AT Rayudu          1
# B Kumar            1
# CH Morris          1
# DA Warner          6
# DJ Bravo           1
# DJG Sammy          1
# DW Steyn           3
# G Gambhir          1
# GH Vihari          2
# I Sharma           1
# MJ McClenaghan     1
# MR Marsh           1
# Mandeep Singh      1
# Mustafizur Rahman  1
# PA Patel           1
# PC Valthaty        1
# R Vinay Kumar      1
# SC Ganguly         1
# SE Marsh           1
# SK Raina           2
# SK Trivedi         1
# SL Malinga         1
# UT Yadav           1
# V Kohli            1
# V Sehwag           2
# WP Saha            1
# YK Pathan          2

# %%
import matplotlib.pyplot as plt
exp_vals = [8.9,87.9,3.1]
exp_labels = ["South Africa","India","UAE"]
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%0.2f%%',radius=1.5,colors = ['green', 'blue', 'red'],explode=[0,0.2,0])
plt.show()
